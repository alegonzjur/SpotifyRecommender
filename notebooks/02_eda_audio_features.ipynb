# %% [markdown]
# # 02 — EDA: Audio Features
#
# Análisis exploratorio de las características de audio extraídas de la API.
# Requiere haber ejecutado el notebook 01 y tener `data/raw/tracks_raw.csv`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

plt.style.use('seaborn-v0_8-whitegrid')
df = pd.read_csv('../data/raw/tracks_raw.csv')
print(df.shape)
df.head()

# %% [markdown]
# ## TODO: completar en la Fase 2 del proyecto
